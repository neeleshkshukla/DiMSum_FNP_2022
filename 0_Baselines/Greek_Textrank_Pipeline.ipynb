# %%
from summa.summarizer import summarize
import os

# %%
valid_dir = '../../../Dataset/FNS2022/Greek/validation/'
annual_reports_dir = "annual_reports"

# %%
file_id = '1'
with open(os.path.join(valid_dir,annual_reports_dir, str(file_id)+'.txt'), "r", encoding='utf-8') as report_file:
    doc = report_file.read()
print(doc)
# Out:
# ΕΤΗΣΙΑ ΟΙΚΟΝΟΜΙΚΗ ΕΚΘΕΣΗ
# για το έτος που έληξε την 31η Δεκεμβρίου 2019
# (Σύμφωνα με το Ν.3556/2007)
#
# Quest Συμμετοχών A.E.
# ΑΡ.Γ.Ε.ΜΗ.:121763701000
# (Πρώην AP.M.A.E.: 5419/06/B/86/02)
# Αργυρουπόλεως 2α, Καλλιθέα
#
# Ετήσια Οικονομική Έκθεση της 31 Δεκεμβρίου 2019
# (Τα ποσά παρουσιάζονται σε χιλιάδες Ευρώ εκτός εάν δηλώνεται διαφορετικά)
#
# δ
#
# Περιεχόμενα
#
# I.
#
# Δηλώσεις εκπροσώπων του Διοικητικού Συμβουλίου
#
# 3
#
# II.
#
# Ετήσια Έκθεση του Διοικητικού Συμβουλίου
#
# 4
#
# III.
#
# Ετήσιες Χρηματοοικονομικές καταστάσεις
#
# 72
#
# IV.
#
# Έκθεση Ελέγχου ορκωτού ελεγκτή λογιστή
#
# 159
#
# -2-
#
# Ετήσια Οικονομική Έκθεση της 31 Δεκεμβρίου 2019
# (Τα ποσά παρουσιάζονται σε χιλιάδες Ευρώ εκτός εάν δηλώνεται διαφορετικά)
#
# δ
#
# -3-
#
# Ο Αναπληρωτής Διευθύνων Σύμβουλος
#
# Μάρκος Μπιτσάκος
#
# Ετήσια Οικονομική Έκθεση της 31 Δεκεμβρίου 2019
# (Τα ποσά παρουσιάζονται σε χιλιάδες Ευρώ εκτός εάν δηλώνεται διαφορετικά)
#
# δ
#
# II.
#
# ...

# %%
summarize(doc, words=1000)
# Out:
# 'Συμβούλιο της Quest Συμμετοχών A.E. την 7η Απριλίου 2020 και έχουν αναρτηθεί στο διαδίκτυο στην ηλεκτρονική\nΟι ετήσιες χρηματοοικονομικές καταστάσεις εγκρίθηκαν από το Διοικητικό Συμβούλιο της Quest Συμμετοχών A.E. την 7η Απριλίου 2020 και υπόκεινται στην έγκριση της ετήσιας Τακτικής Γενικής Συνέλευσης των μετόχων.\nΩς εκ τούτου, ο Όμιλος και η Εταιρεία συνεχίζουν να υιοθετούν την «αρχή της επιχειρηματικής συνέχειας των\nεπιπτώσεις θα εξαρτηθούν από τη διάρκεια, την ένταση και το βαθμό εξάπλωσης της νόσου στην Ελλάδα και\nαποδόσεις από τη συμμετοχή του στην εταιρεία και έχει την ικανότητα να επηρεάζει αυτές τις αποδόσεις μέσω του\nΤα στοιχεία των χρηματοοικονομικών καταστάσεων των εταιρειών του Ομίλου και της Εταιρείας υπολογίζονται\ni. Τα περιουσιακά στοιχεία και υποχρεώσεις μετατρέπονται με τις ισοτιμίες που ισχύουν κατά την ημερομηνία\nΗ υπεραξία και οι αναπροσαρμογές των εύλογων αξιών που προκύπτουν από εξαγορά θυγατρικών εταιρειών στο\nΚατά την πώληση ενσώματων παγίων, οι διαφ
# ...

# %%
valid_dir = '../../../Dataset/FNS2022/Greek/validation/'
annual_reports_dir = "annual_reports"
num_file = 0
for file in os.listdir(os.path.join(valid_dir, annual_reports_dir)):
    try:
        print("Processing File Number: ", num_file)
        num_file = num_file +1 
        file_id = file.split('.')[0]
   
        with open(os.path.join(valid_dir,annual_reports_dir, str(file_id)+'.txt'), "r", encoding='utf-8') as report_file:
            doc = report_file.read()
            summary = summarize(doc, words=1000)
            
        with open('greek/'+ file_id+'_SSC_AI_RG'+'.txt', 'w', encoding='utf-8') as f:
            f.write(str(summary))
        
        if ".DS_Store" in file:
            continue
    except Exception as e:
        print(file, e)
# Out:
# Processing File Number:  0
# Processing File Number:  1
# Processing File Number:  2
# Processing File Number:  3
# Processing File Number:  4
# Processing File Number:  5
# Processing File Number:  6
# Processing File Number:  7
# Processing File Number:  8
# Processing File Number:  9
# Processing File Number:  10
# Processing File Number:  11
# Processing File Number:  12
# Processing File Number:  13
# Processing File Number:  14
# Processing File Number:  15
# Processing File Number:  16
# Processing File Number:  17
# Processing File Number:  18
# Processing File Number:  19
# Processing File Number:  20
